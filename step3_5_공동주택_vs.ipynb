# %%
import pandas as pd
import numpy as np

import re
import os

import geopandas as gpd

# 제출용 코드에서 깔끔하게 보이게,..
import warnings
warnings.filterwarnings("ignore")

# %%
rawdata_path = 'D:/song/my_project/my_project1/rawdata/'
data_path = 'D:/song/my_project/my_project1/data/'

# %%
df_2021 = pd.read_csv('D:/song/my_project/my_project1/rawdata/공동주택가격정보/AL_11_D167_20230130.csv', encoding = 'cp949', low_memory = True)
df_2021.head()
# Out:
#                   고유번호       법정동코드           법정동명  특수지구분코드 특수지구분명 지번  기준연도  \
# 0  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 1  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 2  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 3  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
# 4  1111010100100010000  1111010100  서울특별시 종로구 청운동        1     일반  1  2006
#
#    기준월  공동주택코드  공동주택구분코드 공동주택구분명 특수지명    공동주택명  동명  층명    호명   전용면적  \
# 0    1       3         3      빌라  NaN  청운벽산빌리지   9   1   916  83.61
# 1    1       3         3      빌라  NaN  청운벽산빌리지   9   2   921  83.61
# 2    1       3         3      빌라  NaN  청운벽산빌리지   9   2   922  83.61
# 3    1       3         3      빌라  NaN  청운벽산빌리지   9   2   923  83.61
# 4    1       3         3      빌라  NaN  청운벽산빌리지  10   2  1027  83.61
#
#         공시가격     데이터기준일자
# 0  232000000  2020-03-09
# 1  240000000  2020-03-09
# 2  240000000  2020-03-09
# ...

# %%
df_2021['기준연도'].unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
df_2021['기준연도']
